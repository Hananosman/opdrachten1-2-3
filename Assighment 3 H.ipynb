# %% [markdown]
# # Assighment 3

# %% [markdown]
# * Explain linear regression in your own words *
# Bij een lineaire regressie maak je eigenlijk een passend model bij de data die je hebt. Dit model voorspelt eigenlijk de waarde van een afhankelijke variabele op basis van de waarde van  van een onafhankelijke variable. Dit wordt ook wel een verklarende of een voorspellende variable genoemd. Een rechtlijnige regressie is een rechte lijn in een spreidingsdiagram die zo dicht mogelijk bij de punten in de grafiek ligt.

# %%
import pandas as pd
import seaborn as sns
import sklearn as sk
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

step_data = pd.read_csv("steps.csv", sep=";")
survey_data = pd.read_csv('survey.csv')

# %% [markdown]
# * Create dummy variables for the categorical variables: *

# %%
df=survey_data.merge(step_data, on= "id")
df.head(40)
# Out:
#     id         city  gender    age  hh_size  education          education_1  \
# 0    1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1    2        Lille    Male  35-44        1          3             Bachelor
# 2    3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3    4         Lyon    Male    <25        1          1             Bachelor
# 4    5  Montpellier  Female  25-34        3          4             Bachelor
# 5    6        Lille    Male  35-44        1          1           Vocational
# 6    7  Montpellier    Male  25-34        2          2  Master or doctorate
# 7    8     Bordeaux  Female  25-34        3          4  Master or doctorate
# 8    9        Lille  Female  35-44        4          4           Vocational
# 9   10        Lille  Female  25-34        2          2  Master or doctorate
# 10  11     Bordeaux  Female    <25        2          2             Bachelor
# ...

# %%
df_sub=df[['gender', 'age', 'education', 'weight']]
df_sub.head()
# Out:
#    gender    age  education  weight
# 0    Male  25-34          4    98.0
# 1    Male  35-44          3    77.0
# 2    Male  25-34          2    83.0
# 3    Male    <25          1    80.0
# 4  Female  25-34          4    61.0

# %%
df_sub['age'].value_counts()
# Out:
# 25-34    426
# 35-44    178
# 45-54    147
# <25      125
# 55-64     46
# 65+        7
# Name: age, dtype: int64

# %%
df = pd.get_dummies(df_sub,columns=['age'],drop_first= True)
df.head()
# Out:
#    gender  education  weight  age_35-44  age_45-54  age_55-64  age_65+  \
# 0    Male          4    98.0          0          0          0        0
# 1    Male          3    77.0          1          0          0        0
# 2    Male          2    83.0          0          0          0        0
# 3    Male          1    80.0          0          0          0        0
# 4  Female          4    61.0          0          0          0        0
#
#    age_<25
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0

# %%
x = df.loc[:, ~df.columns.isin(['weight'])]
y = df['weight']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.4,random_state=23) #splits the data into train (70%) and test (30%) data

# %% [markdown]
# Hallo Bob, op één of andere manier lukt het me niet om testdata te maken. Ik heb geprobeerd om verschillende manier, maar heb uiteindelijk de code van een vorige opdracht copy paste. Op één of andere manier lukt dit mij ook niet.

# %%
x_test of y_test
